# %% [markdown]
# # 1.0 — Limpieza de MTF
#
# **Objetivo.** Llevar el dataset crudo de Monitoring the Future a un formato canónico en `data/processed/mtf_clean.csv` aplicando el **orden metodológico** que Carolina señala en las correcciones:
#
# 1. Diagnóstico inicial (shape, dtypes, head, NaN).
# 2. Normalización de tipos (fechas, numéricos como string, categóricos).
# 3. Consistencia de categorías (mayúsculas, acentos, typos).
# 4. Valores imposibles (fuera de rango clínico, fechas futuras).
# 5. Duplicados (análisis de claves, justificación del registro a conservar).
# 6. Outliers (IQR + winsorización vs. eliminación).
# 7. Faltantes (patrón MCAR/MAR/MNAR, decisión de imputar/eliminar).
# 8. Verificación post-acción (shape final, distribuciones, sanity checks).
#
# **Principio rector.** Cada transformación tiene celda markdown de **diagnóstico → decisión → verificación**.

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from wired_apart import config
from wired_apart.dataset import load_mtf, assert_columns

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 160)
np.random.seed(config.RANDOM_SEED)

# %% [markdown]
# ## 1. Diagnóstico inicial

# %%
# df = load_mtf()  # descomentar cuando los datos estén descargados
# df.shape
# df.info()
# df.head()
# df.isna().sum().sort_values(ascending=False).head(20)

# %% [markdown]
# ## 2. Normalización de tipos
# ## 3. Consistencia de categorías
# ## 4. Valores imposibles
# ## 5. Duplicados
# ## 6. Outliers
# ## 7. Faltantes
# ## 8. Verificación final
#
# > _A completar en la Fase 3 del proyecto. Cada paso sigue la estructura_
# > _diagnóstico → decisión → verificación, con justificación explícita._
