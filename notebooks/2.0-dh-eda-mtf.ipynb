# %% [markdown]
# # 2.0 — EDA: Monitoring the Future
#
# **Objetivo.** Entender la estructura del dataset limpio de MTF, identificar patrones, anomalías y oportunidades de feature engineering, y producir visualizaciones exploratorias narradas.
#
# **Preguntas guía (de la Clase 9).**
# - ¿Hay tendencia / estacionalidad / ciclos en las series?
# - ¿Hay valores faltantes y con qué patrón?
# - ¿Cómo es la distribución de las variables clave (sesgo, outliers, multimodalidad)?
# - ¿Qué segmentos son los más informativos (género, cohorte, grado)?

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import matplotlib.pyplot as plt

from wired_apart import config
from wired_apart.plots import apply_project_style, highlight_period, save

apply_project_style()

df = pd.read_csv(config.PROCESSED_DIR / "mtf_clean.csv")
df.head()

# %% [markdown]
# ## Visualizaciones exploratorias
#
# > _A completar en la Fase 4. Cada visualización responde a una pregunta específica_
# > _y se acompaña de una interpretación escrita (no decorativa)._
